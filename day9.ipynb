# %% [markdown]
# <a href="https://colab.research.google.com/github/rhgurqo52/ai/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Q1

n = input("숫자를 포함한 문자열을 입력하세요 >>>")
alp=[]
num=[]
for i in n:
  if i.isalpha():
    alp.append(i)
  else:
    num.append(i)

print(f'문자:{alp}')
print(f'숫자:{num}')
# Out:
# 숫자를 포함한 문자열을 입력하세요 >>>123asd
# 문자:['a', 's', 'd']
# 숫자:['1', '2', '3']

# %%
# (영어)알파벳과 숫자를 섞어서 입력을 받아서 숫자와 문자를 
# 분리하여 출력하는 프로그램을 작성하시오.

# [입력]
# 숫자를 포함한 문자열을 입력하세요 >>> 123abc45

# [출력]
# 문자 : abc
# 숫자 : 12345

str = input('숫자를 포함한 문자열을 입력하세요 >>> ')
al = ''
no = ''

for i in str:
  if i.isalpha():
    al+=i
  elif i.isdigit():
    no+=i

print(f'문자:{al}')
print(f'숫자:{no}')
# Out:
# 숫자를 포함한 문자열을 입력하세요 >>> 123asd
# 문자:asd
# 숫자:123

# %%
# Q2

str = input('숫자를 포함한 문자열을 입력하세요 >>> ')
cnt1 = 0
al = ''
cnt2 = 0
no = ''

for i in str:
  if i.isalpha():
    cnt1+=1
    al+=i
  elif i.isdigit():
    cnt2+=2
    no+=i

print(f'문자({cnt1}):{al}')
print(f'숫자({cnt2}):{no}')
# Out:
# 숫자를 포함한 문자열을 입력하세요 >>> 123asd
# 문자(3):asd
# 숫자(6):123

# %%
# 문자와 숫자의 개수를 각각 포함하여 출력하세요

# 숫자를 포함한 문자열을 입력하세요 >>> 1234asdf324as
# 문자(6) :  asdfas
# 숫자(7) :  1234324


str = input('숫자를 포함한 문자열을 입력하세요 >>> ')

al = ''
no = ''

for i in str:
  if i.isalpha():
    al = al + i
  elif i.isdigit():
    no = no + i

print(f'문자({len(al)}) : {al}')
print(f'숫자({len(no)}) : {no}')

# %%
str = input('숫자를 포함한 문자열을 입력하세요 >>> ')
cnt1 = 0
al = ''
cnt2 = 0
no = ''

for i in str:
  if i.isalpha():
    cnt1+=1
    al+=i
  elif i.isdigit():
    cnt2+=2
    no+=i

print(f'문자({cnt1}):{al}')
print(f'숫자({cnt2}):{no}')

# %%
# by 김현엽

n=input("입력값>>")
a=""
b=""
c=0
d=0
for i in n:
    if i in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ":
        c=c+1
        b=b+i    
    elif i in '0123456789':
        d=d+1
        a=a+i
    
        
print(f"문자{c}: {b}")     
print(f"숫자{d}: {a}")
# Out:
# 숫자를 포함한 문자열을 입력하세요 >>> $#%^123asd
# 문자(7):$#%^asd
# 숫자(6):123

# %%
# by 김정관
a = input("숫자를 포함한 문자열을 입력하세요.>>>")
n = ''
al = ''
al_list = []
n_list = '1234567890'

# 알파벳 리스트
for i in range(97,123) :
  al_list.append(chr(i))

for i in range(65,91) :
  al_list.append(chr(i))

# 숫자 리스트

for i in a :
  if i in al_list :
    al = al + i
  elif i in n_list :
    n = n + i

print(f'문자({len(al)}) : {al}')
print(f'숫자({len(n)}) : {n}')
# Out:
# 숫자를 포함한 문자열을 입력하세요.>>>123asd
# 문자(3) : asd
# 숫자(3) : 123

# %%
# by 이지은

str = input('숫자를 포함한 문자열을 입력하세요 >>> ')
cnt1 = 0
al = ''
cnt2 = 0
no = ''

for i in str:
  if i == '1' or i == '2' or i == '3' or i == '4' or i == '5' or i == '6' or i == '7' or i == '8' or i == '9' or i == '0':
    cnt2+=2
    no+=i
  else:
    cnt1+=1
    al+=i

print(f'문자({cnt1}):{al}')
print(f'숫자({cnt2}):{no}')
# Out:
# 숫자를 포함한 문자열을 입력하세요 >>> 123asd
# 문자(3):asd
# 숫자(6):123

# %%
# by 이재원
def str_slide( pr ):
    s = "1234567890"
    a = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"
    str = "";
    int = "";
    count_int = 0; 
    count_str = 0;
    
    for i in pr:
        if i in s:
            int += f"{i} ";
            count_int +=1 ;
        elif i in a:
            str += f"{i} ";
            count_str += 1;            
            
    print(f"입력 숫자 : {int} {count_int}개");
    print(f"입력 문자 : {str} {count_str}개");
            
pr = input("입력 > ");
str_slide(pr);
# Out:
# 입력 > 123asd
# 입력 숫자 : 1 2 3  3개
# 입력 문자 : a s d  3개

# %%
# by 임진석

str1 = input('알파벳과 숫자를 입력 : ')
al = ''
num = ''
cnt_al = 0
cnt_num = 0
for i in str1:
    if i >='A' and i <= 'z':
        al += i
        cnt_al += 1
    elif i >= '0' and i <='9':
        num += i
        cnt_num += 1

        
print(f'문자({cnt_al}) : {al}')
print(f'숫자({cnt_num}) : {num}')
# Out:
# 알파벳과 숫자를 입력 : 123qwe@$#^^%%$
# 문자(3) : qwe
# 숫자(3) : 123

# %%
# by 민지수

str=input('숫자를 포함한 문자열을 입력하세요>>> ')

ai=""
no=""

for i in str :
    if 64<ord(i)<123:
        ai=ai+i
    
    elif 48<ord(i)<58:
        no=no+i
    
    
print(f'문자({len(ai)}) : ',ai)
print(f'숫자({len(no)}): ',no)

# %%
str1 = input('알파벳과 숫자를 입력 : ')
al = ''
num = ''
cnt_al = 0
cnt_num = 0
for i in str1:
    if i >='A' and i <= 'Z':
        al += i
        cnt_al += 1
    elif i >='a' and i <= 'z':
        al += i
        cnt_al += 1
    elif i >= '0' and i <='9':
        num += i
        cnt_num += 1

        
print(f'문자({cnt_al}) : {al}')
print(f'숫자({cnt_num}) : {num}')
# Out:
# 알파벳과 숫자를 입력 : 123asdASDASD!@$@$^#$^
# 문자(9) : asdASDASD
# 숫자(3) : 123

# %%
# 정규 표현식으로 고쳤습니다.
import re;
def str_slide( pr ):
    n = re.compile("[0-9]");
    a = re.compile("[a-zA-Z]");
    str = "";
    int = "";
    count_int = 0; 
    count_str = 0;
    
    for i in pr:
        if a.search(i):
            int += f"{i} ";
            count_int +=1 ;
        elif n.search(i):
            str += f"{i} ";
            count_str += 1;            
            
    print(f"입력 숫자 : {int} {count_int}개");
    print(f"입력 문자 : {str} {count_str}개");
            
pr = input("입력 > ");
str_slide(pr);

# %%
############################################################
# 알고리즘
############################################################
# '알고리즘은 문제나 과제를 해결하기 위한 처리 절차를 구체적인 순서로 표현한
# 아이디어나 생각'
# 알고리즘 표현 방법은 수도코드(pseudo code), 순서도(flow chart)가 있다

# 프로그램 작성 순서
# 기획 - 설계(알고리즘) - 프로그래밍 - 디버그 - 문서작성

# 좋은 알고리즘
# 알기 쉽고, 속도가 빠르고, 효율적이고(메모리를 적게 사용), 재이용이 쉽다.

# 왜 알고리즘 ?
# 좋은 프로그램을 만들 수 있고, 좋은 프로그램인지 판단할 수 있고
# 프로그램 작성을 효율적으로 할 수 있고 프로그래밍 기술을 향상시키는데 큰 도움이 된다.

# 좋은 알고리즘의 조건
# 결과를 얻을 수 있어야 하고 반드시 종료되어야 한다.

# 알고리즘 세가지 기본형
# 1. 순차구조 : 처음부터 순서대로 처리
# 2. 선택구조 : 조건식 if
# 3. 반복구조 : 반복문 for while



# 순서도 flow 차트, 흐름도
# 프로그래밍 언어를 사용하지 않고 알고리즘을 기술하는 방법
# 처리와 절차를 시각적으로 표현한다.
# 자신이 생각하고 있는 알고리즘이 올바른지, 처리와 절차에 문제가 없는지를
# 시각적으로 확인 할 수 있고 다른 사람에게도 쉽게 전달할 수 있는 특징이 있다.

# 주의사항 !
# 처리 기호나 판단 기호가 많아지면 흐름이 복잡하게 꼬인다.
# 1. 입력은 반드시 위에서 들어가도록 만든다.
# 2. 판단기호로부터 나오는 흐름선에는 Yes No를 확실하게 기입한다.
# 3. 입력선이나 출력선이 없는 처리 기호는 만들지 않는다.

# %% [markdown]
# ![기본.jpg](data:image/jpeg;base64,...)

# %%
# 유명한 알고리즘이란?
# 유명한 알고리즘을 배우는 것은 프로그래밍 기술향상에 커다란 도움이 된다.

# 탐색 : Linear Search, Binary Search, Hash Search
# 정렬 : Selection Sort, Bubble Sort, Insertion Sort, Quick Sort
# Sieve of Eratosthenes, Euclid Algorithm

# 가우스 소거법, 사다리꼴 법칙, 디익스트라 알고리즘, 이분법, 뉴턴법...
# KMP 알고리즘, BM 알고리즘......

# %%
# 선형탐색법 Linear Search

# 맨 앞부터 순서대로 찾는 값이 나올때까지 조사하는 알고리즘
# 알고리즘은 단순하여 이해는 쉽지만 탐색 효율 자체는 그다지 좋은 편은 아니다.

# 탐색시작      4 2 3 5     <- 내가 찾는수 5
              # --
              #    --
              #       --
              #          --      <- 처음부터 순차적으로 하나씩 확인한다.

# %% [markdown]
# ![선형탐색법_복습.jpg](data:image/jpeg;base64,...)

# %%
# 이진 탐색법 Binary Search

# 탐색 대상 데이터들이 미리 오름차순 또는 내림차순으로 정렬이 되어 있어야만 한다. 
# 탐색하는 범위를 절반씩 추려나가면서 탐색을 한다.  

# 0  1   2   3   4  5   6  index 
# 11 13 17 19 23 29 31 data


# 0  1  2   3   4   5   6      step 1 가운데 인덱스  즉 3을 열여서 확인한다. 
#            19                            찾고 있는 17이 아니다. 그런데 정렬되어 있다는 전제
#                                           조건이 있으므로 이후의 모든 데이터는 절대 찾고 있는
#                                           17이 될수 없다. 
# 0   1   2                       step 2 새로운 범위의 가운데 인덱스 즉 1을 열어 확인한다. 
#     13                                    찾고 있는 17이 아니다. 그런데 정렬되어 있다는 전제
#                                           조건이 있으므로 이전의 모든 데이터는 절대 찾고 있는
#                                           17이 될수 없다. 
# 2                                step 3 마지막 요소만 남게 되었지만 찾고 있는 17이 아예 없는
# 17                                        경우도 발생할 수 있으므로 처리해 주어야 하지만 지금은
#                                           마지막 index 2가 찾고 있는 17이므로 검색을 종료한다.

# %%
# 이진 탐색법의 알고리즘
# 1. 가운데 요소를 선택하는 처리(인덱스의 평균을 계산하여 구한다. )
# 2. 가운데 데이터와 찾는 데이터를 비교하는 처리
# 3. 탐색 범위를 절반으로 줄이는 처리 

# 요소의 갯수가 짝수 일때는 어떻게 해야 할까!!!
            # 0   1   2   3   4  5  
            # 11 13 17 19 23 29
#                       -- --
# 요소의 갯수가 짝수 일때는 가운데 요소가 2개라는 것을 알수 있다. 
# 이 경우 어느쪽을 선택해야 한다고 정해진 것은 없다. 단지 둘 중 하나만
# 선택하면 된다. 따라서 같은 공식으로 계산해 보면
# (0+5) / 2 = 2.5
# 소수를 정수화 하는 방법으로는 1.반올림 2. 올림 3.버림 있다. 
# 하지만 제일 간단한 방법은 3. 버림 이 제일 쉬운 처리이다. 
# 정수형 변수에 넣기만 하면 자동으로 소수 부분은 잘려 나가기 때문에
# 쉽게 정수 부분만 얻을수 있게 된다.

# %% [markdown]
# ![이진탐색법_복습.jpg](data:image/jpeg;base64,...)

# %%
# 해시 탐색법
# 데이터의 내용과 저장한 곳의 '요소'를 연계해 두어 극히(***) 짧은 시간안에 검색 할 수 있도록 고안된 알고리즘

#           해시 값 = 데이터 % 저장공간의 수 <- 해시함수

# 미리 해시 함수를 사용하여 데이터를 저장하는 장소를 정해서 검색 시간을 놀라울 정도록 단축 시킬 수 있다.

# %%
# 해시 탐색 알고리즘
# 1. 해시함수를 통해 데이터를 저장하는 알고리즘
# 2. 해시함수를 통해 데이터를 검색하는 알고리즘

# 배열을 2개 사용한다.
# 정렬 전에 준비된 데이터의 배열과 데이터를 저장할 배열을 준비한다.
# 데이터를 저장할 배열의 수는 데이터 갯수의 1.5배에서 2배로 준비하는 것이 좋다.
# 검색 속도와메모리 효율면에서 적당 크기는 1.5배에서 2배로 알려져 있다.

# %% [markdown]
# ![해시탐색법_복습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![해시탐색법_복습.jpg](data:image/jpeg;base64,...)

# %%
# 단순 선택법
# 1. 탐색 범위의 최소값을 찾는 처리
# 2. 찾을 최소값을 맨 앞의 요소와 교환하는 처리

# %% [markdown]
# ![단순선택법_복습.jpg](data:image/jpeg;base64,...)

# %%
# 단순 교환법
# 인접한 2개의 데이터를 교환하는 처리를 반복하여 전체를 정렬한다.
# 속도가 느린 알고리즘

# 알고리즘
# 1. 오른쪽 끝 요소부터 차례로 인접한 데이터를 오름차순 정렬하여 교환한다.
# 2. 왼쪽 끝부터 순서대로 하나씩 데이터를 정렬하여 확정시킨다.

# %% [markdown]
# ![단순교환법_복습.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![단순교횐법_복습.jpg](data:image/jpeg;base64,...)
